# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavi54-hub/Vaishu-54/blob/main/python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#python programming
print(123)

print("hello world")#welcoming
# Out:
# 123
# hello world

# %%
print("vaishu")
# Out:
# vaishu

# %%
print('welcome to python world')
# Out:
# welcome to python world

# %%
a=10
a
# Out:
# 10

# %%
x = 10
x
# Out:
# 10

# %%
a=54
print(a)
type(a)
# Out:
# 54
# int

# %%
data =20
data
# Out:
# 20

# %%
a="lovely"
type(a)
# Out:
# str

# %%
if 1<8:
  print("1 is less")
else:
  print("1 is not less")
# Out:
# 1 is less

# %%
if 3>8:
  print("3 is less than 8")

# %%
a=90,20,"50","jv"
a
type(a)
# Out:
# tuple

# %%
print("\n")

# %%
X=10
y=20
print(y)
# Out:
# 20

# %%
a=110
b=90
print(a,b)
# Out:
# 110 90

# %%
import keyword
keyword.kwlist #there are certain keywords in python which does only specific task and u cannot use this keywords to do anything else apart from what it is define to do
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
# a is variable 10 is value
a=10
b="vaishu"
print(a)
print(b)
type(b)
# Out:
# 10
# vaishu
# str

# %%
x=y=z="vaishu"
print(x)
print(y)
print(z)
#
# Out:
# vaishu
# vaishu
# vaishu

# %%
A=a
A
# Out:
# 10

# %%
x,y,z="vaishu","sanju","sriju"
print(x)
print(y)
print(z)
# Out:
# vaishu
# sanju
# sriju

# %%
x="python"
y="is"
z="is a programming language"
print(x,y,z)
# Out:
# python is is a programming language

# %%
a=False
type(a)
# Out:
# bool

# %%
x=2+1j
type(x)
# Out:
# complex
