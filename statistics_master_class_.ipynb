# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavi54-hub/Vaishu-54/blob/main/statistics_master_class_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# print the list
print('my_list')
# Out:
# my_list

# %%
my_list = ['wubba', 'lubba', 'dub', 'dub']

# %%
# create a new list
my_list = [1,2,3,4,5,6,7,8,12,7,8]

# %%
# print the list
my_list
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 12, 7, 8]

# %%
len(my_list)
# Out:
# 11

# %%
# print the list
print(my_list)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 12, 7, 8]

# %%
# Append to the end of the list
my_list.append('Append me!')

# %%
print(my_list)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 12, 7, 8, 'Append me!']

# %%
len(my_list)
# Out:
# 12

# %%
my_list.append([1,2,3])

# %%
my_list
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 12, 7, 8, 'Append me!', [1, 2, 3]]

# %%
my_list.extend(['wubba','lubba','dub dub'])

# %%
print(my_list)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 12, 7, 8, 'Append me!', [1, 2, 3], 'wubba', 'lubba', 'dub dub']

# %%
len(my_list)
# Out:
# 16

# %%
# pop off the 0 indexed item
my_list.pop()
# Out:
# 'dub dub'

# %%
print(my_list)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 12, 7, 8, 'Append me!', [1, 2, 3], 'wubba', 'lubba']

# %%
# assign the popped element,remember default popped index is-1
my_list.pop(-1)
# Out:
# 'lubba'

# %%
len(my_list)
# Out:
# 14

# %%
# remove the element which you want to
my_list.remove('wubba')

# %%
# show
print(my_list)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 12, 7, 8, 'Append me!', [1, 2, 3]]

# %%
my_list.remove(1)

# %%
print(my_list)
# Out:
# [2, 3, 4, 5, 6, 7, 8, 12, 7, 8, 'Append me!', [1, 2, 3]]

# %%
len(my_list)
# Out:
# 12

# %%
my_list.clear()

# %%
print(my_list)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 12, 7, 8]

# %%
# count the number of times element 1 occurs in my_list
my_list.count(1)
# Out:
# 1

# %%
 my_list.index(6)
# Out:
# 5

# %%
new_list=[2,6,5,4]

# %%
new_list.sort()

# %%
print(new_list)
# Out:
# [2, 4, 5, 6]

# %%
# use the reverse boolean to set the ascending or descending order
new_list.sort(reverse=True)
print(new_list)
# Out:
# [6, 5, 4, 2]

# %%
boolean_list = [True,False]

# %%
boolean_list.sort(reverse=True)

# %%
print(boolean_list)
# Out:
# [True, False]

# %%
boolean_list.sort(reverse=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1747376298.py in <cell line: 0>()
# ----> 1 boolean_list.sort(reverse=True)
#
# NameError: name 'boolean_list' is not defined

# %%
my_list = ['a','e','x','b','c']

# %%
print(my_list)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 12, 7, 8]

# %%
my_list.reverse()

# %%
print(my_list)
# Out:
# [8, 7, 12, 8, 7, 6, 5, 4, 3, 2, 1]
